# %%
# Change the values below to change your data selection.

FILE=1                # There are 48 files.
CHANNEL=0             # There are 2 channels
SAMPLE_START=114000   # Start of the sample in the file.
SAMPLE_SIZE=4000      # Number of readings (360 per second).

# %%
pip install tqdm
# Out:
# Collecting tqdmNote: you may need to restart the kernel to use updated packages.
#
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.3/78.3 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\msi gaming\appdata\roaming\python\python310\site-packages (from tqdm) (0.4.5)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.66.1
#   WARNING: The script tqdm.exe is installed in 'c:\Users\MSI GAMING\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install wfdb
# Out:
# Collecting wfdb
#   Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#      -------------------------------------- 160.0/160.0 kB 1.6 MB/s eta 0:00:00
# Collecting SoundFile>=0.10.0
#   Downloading soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 5.8 MB/s eta 0:00:00
# Collecting requests>=2.8.1
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.6/62.6 kB ? eta 0:00:00
# Collecting scipy>=1.0.0
#   Downloading scipy-1.11.2-cp310-cp310-win_amd64.whl (44.0 MB)
#      ---------------------------------------- 44.0/44.0 MB 5.4 MB/s eta 0:00:00
# Collecting numpy>=1.10.1
#   Downloading numpy-1.25.2-cp310-cp310-win_amd64.whl (15.6 MB)
#      ---------------------------------------- 15.6/15.6 MB 8.7 MB/s eta 0:00:00
# Collecting pandas>=1.3.0
#   Downloading pandas-2.1.0-cp310-cp310-win_amd64.whl (11.1 MB)
#      ---------------------------------------- 11.1/11.1 MB 8.7 MB/s eta 0:00:00
# Collecting matplotlib>=3.2.2
#   Downloading matplotlib-3.7.3-cp310-cp310-win_amd64.whl (7.5 MB)
#      ---------------------------------------- 7.5/7.5 MB 8.4 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-win_amd64.whl (56 kB)
#      ---------------------------------------- 56.1/56.1 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\msi gaming\appdata\roaming\python\python310\site-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\msi gaming\appdata\roaming\python\python310\site-packages (from matplotlib>=3.2.2->wfdb) (21.3)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.0-cp310-cp310-win_amd64.whl (470 kB)
#      -------------------------------------- 470.4/470.4 kB 9.8 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.0.0-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\msi gaming\appdata\roaming\python\python310\site-packages (from matplotlib>=3.2.2->wfdb) (3.0.9)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.42.1-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 9.0 MB/s eta 0:00:00
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ------------------------------------- 341.8/341.8 kB 10.7 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#      ------------------------------------- 502.5/502.5 kB 10.5 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ---------------------------------------- 61.5/61.5 kB ? eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.0.4-py3-none-any.whl (123 kB)
#      -------------------------------------- 123.9/123.9 kB 7.1 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      -------------------------------------- 158.3/158.3 kB 9.3 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.2.0-cp310-cp310-win_amd64.whl (96 kB)
#      ---------------------------------------- 96.9/96.9 kB 5.8 MB/s eta 0:00:00
# Collecting cffi>=1.0
#   Downloading cffi-1.15.1-cp310-cp310-win_amd64.whl (179 kB)
#      ------------------------------------- 179.1/179.1 kB 10.6 MB/s eta 0:00:00
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
#      -------------------------------------- 118.7/118.7 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\msi gaming\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Installing collected packages: pytz, urllib3, tzdata, pycparser, pillow, numpy, kiwisolver, idna, fonttools, cycler, charset-normalizer, certifi, scipy, requests, pandas, contourpy, cffi, SoundFile, matplotlib, wfdb
# Successfully installed SoundFile-0.12.1 certifi-2023.7.22 cffi-1.15.1 charset-normalizer-3.2.0 contourpy-1.1.0 cycler-0.11.0 fonttools-4.42.1 idna-3.4 kiwisolver-1.4.5 matplotlib-3.7.3 numpy-1.25.2 pandas-2.1.0 pillow-10.0.0 pycparser-2.21 pytz-2023.3.post1 requests-2.31.0 scipy-1.11.2 tzdata-2023.3 urllib3-2.0.4 wfdb-4.1.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\MSI GAMING\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\MSI GAMING\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\MSI GAMING\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install biosppy
# Out:
# Collecting biosppy
#   Downloading biosppy-1.0.0-py2.py3-none-any.whl (106 kB)
#      -------------------------------------- 107.0/107.0 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\msi gaming\appdata\local\programs\python\python310\lib\site-packages (from biosppy) (1.11.2)
# Collecting h5py
#   Downloading h5py-3.9.0-cp310-cp310-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 2.7/2.7 MB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\msi gaming\appdata\roaming\python\python310\site-packages (from biosppy) (1.16.0)
# Requirement already satisfied: numpy in c:\users\msi gaming\appdata\local\programs\python\python310\lib\site-packages (from biosppy) (1.25.2)
# Requirement already satisfied: matplotlib in c:\users\msi gaming\appdata\local\programs\python\python310\lib\site-packages (from biosppy) (3.7.3)
# Collecting joblib
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ------------------------------------- 302.2/302.2 kB 19.5 MB/s eta 0:00:00
# Collecting bidict
#   Downloading bidict-0.22.1-py3-none-any.whl (35 kB)
# Collecting shortuuid
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.0-cp310-cp310-win_amd64.whl (9.2 MB)
#      ---------------------------------------- 9.2/9.2 MB 20.4 MB/s eta 0:00:00
# Collecting opencv-python
#   Downloading opencv_python-4.8.0.76-cp37-abi3-win_amd64.whl (38.1 MB)
#      ---------------------------------------- 38.1/38.1 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\msi gaming\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->biosppy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\msi gaming\appdata\roaming\python\python310\site-packages (from matplotlib->biosppy) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\msi gaming\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->biosppy) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\msi gaming\appdata\roaming\python\python310\site-packages (from matplotlib->biosppy) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\msi gaming\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->biosppy) (4.42.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\msi gaming\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->biosppy) (10.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\msi gaming\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->biosppy) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\msi gaming\appdata\roaming\python\python310\site-packages (from matplotlib->biosppy) (2.8.2)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, shortuuid, opencv-python, joblib, h5py, bidict, scikit-learn, biosppy
# Successfully installed bidict-0.22.1 biosppy-1.0.0 h5py-3.9.0 joblib-1.3.2 opencv-python-4.8.0.76 scikit-learn-1.3.0 shortuuid-1.0.11 threadpoolctl-3.2.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script shortuuid.exe is installed in 'c:\Users\MSI GAMING\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import wfdb as wf
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from biosppy.signals import ecg
from glob import glob

# %%
def get_records():
    """ Get paths for data in data/mit/ directory """
    # There are 3 files for each record
    # *.atr is one of them
    #path_source = './MIT-BIH/*.atr'
    path_source = './MIT-BIH/*.atr'
    paths = glob(path_source)

    # Get rid of the extension
    paths = [path[:-4] for path in paths]
    paths.sort()

    return paths

# %%
records = get_records()
print('Total files: ', len(records))
realbeats = ['N','L','R','B','A','a','J','S','V','r',
             'F','e','j','n','E','/','f','Q','?']
# Out:
# Total files:  48

# %%
for path in records:
    pathpts = path.split('/')
    fn = pathpts[-1]
    print('Loading file:', path)

    # Read in the data
    record = wf.rdsamp(path)
    annotation = wf.rdann(path, 'atr')

    # Print some meta informations
    print('    Sampling frequency used for this record:', record[1].get('fs'))
    print('    Shape of loaded data array:', record[0].shape)
    print('    Number of loaded annotations:', len(annotation.num))
    
    # Get the ECG values from the file.
    data = record[0].transpose()
# Out:
# Loading file: ./MIT-BIH\100
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2274
# Loading file: ./MIT-BIH\101
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1874
# Loading file: ./MIT-BIH\102
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2192
# Loading file: ./MIT-BIH\103
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2091
# Loading file: ./MIT-BIH\104
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2311
# Loading file: ./MIT-BIH\105
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2691
# Loading file: ./MIT-BIH\106
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2098
# Loading file: ./MIT-BIH\107
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2140
# Loading file: ./MIT-BIH\108
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1824
# Loading file: ./MIT-BIH\109
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2535
# Loading file: ./MIT-BIH\111
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2133
# Loading file: ./MIT-BIH\112
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2550
# Loading file: ./MIT-BIH\113
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1796
# Loading file: ./MIT-BIH\114
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1890
# Loading file: ./MIT-BIH\115
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1962
# Loading file: ./MIT-BIH\116
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2421
# Loading file: ./MIT-BIH\117
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1539
# Loading file: ./MIT-BIH\118
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2301
# Loading file: ./MIT-BIH\119
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2094
# Loading file: ./MIT-BIH\121
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1876
# Loading file: ./MIT-BIH\122
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2479
# Loading file: ./MIT-BIH\123
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1519
# Loading file: ./MIT-BIH\124
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1634
# Loading file: ./MIT-BIH\200
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2792
# Loading file: ./MIT-BIH\201
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2039
# Loading file: ./MIT-BIH\202
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2146
# Loading file: ./MIT-BIH\203
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3108
# Loading file: ./MIT-BIH\205
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2672
# Loading file: ./MIT-BIH\207
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2385
# Loading file: ./MIT-BIH\208
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3040
# Loading file: ./MIT-BIH\209
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3052
# Loading file: ./MIT-BIH\210
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2685
# Loading file: ./MIT-BIH\212
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2763
# Loading file: ./MIT-BIH\213
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3294
# Loading file: ./MIT-BIH\214
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2297
# Loading file: ./MIT-BIH\215
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3400
# Loading file: ./MIT-BIH\217
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2280
# Loading file: ./MIT-BIH\219
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2312
# Loading file: ./MIT-BIH\220
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2069
# Loading file: ./MIT-BIH\221
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2462
# Loading file: ./MIT-BIH\222
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2634
# Loading file: ./MIT-BIH\223
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2643
# Loading file: ./MIT-BIH\228
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2141
# Loading file: ./MIT-BIH\230
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2466
# Loading file: ./MIT-BIH\231
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2011
# Loading file: ./MIT-BIH\232
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 1816
# Loading file: ./MIT-BIH\233
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 3152
# Loading file: ./MIT-BIH\234
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2764

# %%
for path in records:
    pathpts = path.split('/')
    fn = pathpts[-1]
    print('Loading file:', path)

    # Read in the data
    record = wf.rdsamp(path)
    annotation = wf.rdann(path, 'atr')

    # Print some meta informations
    print('    Sampling frequency used for this record:', record[1].get('fs'))
    print('    Shape of loaded data array:', record[0].shape)
    print('    Number of loaded annotations:', len(annotation.num))
    
    # Get the ECG values from the file.
    data = record[0].transpose()

    # Generate the classifications based on the annotations.
    # 0.0 = undetermined
    # 1.0 = normal
    # 2.0 = abnormal
    cat = np.array(annotation.symbol)
    rate = np.zeros_like(cat, dtype='float')
    for catid, catval in enumerate(cat):
        if (catval == 'N'):
            rate[catid] = 1.0 # Normal
        elif (catval in realbeats):
            rate[catid] = 2.0 # Abnormal
    rates = np.zeros_like(data[0], dtype='float')
    rates[annotation.sample] = rate
    
    indices = np.arange(data[0].size, dtype='int')

    # Process each channel separately (2 per input file).
    for channelid, channel in enumerate(data):
        chname = record[1].get('sig_name')[channelid]
        print('    ECG channel type:', chname)
        
        # Find rpeaks in the ECG data. Most should match with
        # the annotations.
        out = ecg.ecg(signal=channel, sampling_rate=360, show=False)
        rpeaks = np.zeros_like(channel, dtype='float')
        rpeaks[out['rpeaks']] = 1.0
        
        beatstoremove = np.array([0])

        # Split into individual heartbeats. For each heartbeat
        # record, append classification (normal/abnormal).
        beats = np.split(channel, out['rpeaks'])
        for idx, idxval in enumerate(out['rpeaks']):
            firstround = idx == 0
            lastround = idx == len(beats) - 1

            # Skip first and last beat.
            if (firstround or lastround):
                continue

            # Get the classification value that is on
            # or near the position of the rpeak index.
            fromidx = 0 if idxval < 10 else idxval - 10
            toidx = idxval + 10
            catval = rates[fromidx:toidx].max()
            
            # Skip beat if there is no classification.
            if (catval == 0.0):
                beatstoremove = np.append(beatstoremove, idx)
                continue

            # Normal beat is now classified as 0.0 and abnormal is 1.0.
            catval = catval - 1.0

            # Append some extra readings from next beat.
            beats[idx] = np.append(beats[idx], beats[idx+1][:40])

            # Normalize the readings to a 0-1 range for ML purposes.
            beats[idx] = (beats[idx] - beats[idx].min()) / beats[idx].ptp()

            # Resample from 360Hz to 125Hz
            newsize = int((beats[idx].size * 125 / 360) + 0.5)
            beats[idx] = signal.resample(beats[idx], newsize)

            # Skipping records that are too long.
            if (beats[idx].size > 187):
                beatstoremove = np.append(beatstoremove, idx)
                continue

            # Pad with zeroes.
            zerocount = 187 - beats[idx].size
            beats[idx] = np.pad(beats[idx], (0, zerocount), 'constant', constant_values=(0.0, 0.0))

            # Append the classification to the beat data.
            beats[idx] = np.append(beats[idx], catval)

        beatstoremove = np.append(beatstoremove, len(beats)-1)

        # Remove first and last beats and the ones without classification.
        beats = np.delete(beats, beatstoremove)

        # Save to CSV file.
        savedata = np.array(list(beats[:]), dtype=np.float)
        outfn = 'File CSV\\'+fn+'_'+chname+'.csv'
        print('    Generating ', outfn)
        with open(outfn, "wb") as fin:
            np.savetxt(fin, savedata, delimiter=",", fmt='%f')
# Out:
# Loading file: ./MIT-BIH\100
#     Sampling frequency used for this record: 360
#     Shape of loaded data array: (650000, 2)
#     Number of loaded annotations: 2274
#     ECG channel type: MLII
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\UIT\NCKHSV\Năm 2023\01_View_MITDB_Data.ipynb Cell 9 in 9
#      <a href='vscode-notebook-cell:/d%3A/UIT/NCKHSV/N%C4%83m%202023/01_View_MITDB_Data.ipynb#X10sZmlsZQ%3D%3D?line=93'>94</a> beatstoremove = np.append(beatstoremove, len(beats)-1)
#      <a href='vscode-notebook-cell:/d%3A/UIT/NCKHSV/N%C4%83m%202023/01_View_MITDB_Data.ipynb#X10sZmlsZQ%3D%3D?line=95'>96</a> # Remove first and last beats and the ones without classification.
# ---> <a href='vscode-notebook-cell:/d%3A/UIT/NCKHSV/N%C4%83m%202023/01_View_MITDB_Data.ipynb#X10sZmlsZQ%3D%3D?line=96'>97</a> beats = np.delete(beats, beatstoremove)
#      <a href='vscode-notebook-cell:/d%3A/UIT/NCKHSV/N%C4%83m%202023/01_View_MITDB_Data.ipynb#X10sZmlsZQ%3D%3D?line=98'>99</a> # Save to CSV file.
#     <a href='vscode-notebook-cell:/d%3A/UIT/NCKHSV/N%C4%83m%202023/01_View_MITDB_Data.ipynb#X10sZmlsZQ%3D%3D?line=99'>100</a> savedata = np.array(list(beats[:]), dtype=np.float)
#
# File c:\Users\MSI GAMING\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:5244, in delete(arr, obj, axis)
#    5241     except AttributeError:
#    5242         pass
# -> 5244 arr = asarray(arr)
#    5245 ndim = arr.ndim
#    5246 arrorder = 'F' if arr.flags.fnc else 'C'
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2273,) + inhomogeneous part.
